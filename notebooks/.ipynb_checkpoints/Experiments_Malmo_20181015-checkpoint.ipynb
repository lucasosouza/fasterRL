# %%
import os
import numpy as np
from collections import defaultdict
import pandas as pd
import matplotlib.pyplot as plt
import json
# %matplotlib inline

from tensorboard.backend.event_processing import event_accumulator
from collections import defaultdict

# %%
# list experiments
NUM_EXPERIMENTS = 2
root = "/mnt/storage/log-experiments/"
log_root = root + "logs/"

# only want last 15 experiments
# experiments = [f for f in os.listdir(log_root) if f[-4:] == 'json']

# place them in a dictionary
exp_dict = {}
for exp in os.listdir(log_root)[-NUM_EXPERIMENTS:]:
    if exp[-4:] == 'json':
        exp_id = exp[:-5]
        with open(log_root+exp, "rb") as f:
            exp_dict[exp_id] = json.load(f)
            
# convert dictionary to a dataframe
experiments_df = pd.DataFrame.from_dict(exp_dict, orient='index')

# %%
experiments_df.shape
# Out:
# (2, 27)

# %%
experiments_df.index
# Out:
# Index(['DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030813-48'], dtype='object')

# %%
experiments_df.head()
# Out:
#                                                    SEARCH_METHOD  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...    hypothesis
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...    hypothesis
#
#                                                         DEFAULT_ENV_NAME  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...  MinecraftBasicNew-v0
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...  MinecraftBasicNew-v0
#
#                                                            METHOD  NUM_TRIALS  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...  DQN_Malmo_Seq          50
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...  DQN_Malmo_Seq          50
#
#                                                     DEBUG  MAX_GAMES_PLAYED  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...   True               150
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...   True               150
#
#                                                     MEAN_REWARD_BOUND  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                950
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                950
#
#                                                     NUMBER_EPISODES_MEAN  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                    10
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                    10
#
#                                                     NUM_AGENTS  SHARING  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...           2     True
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...           2    False
#
#                                                      ...    GRAD_L2_CLIP  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...   ...               1
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...   ...               1
#
#                                                     SYNC_TARGET_FRAMES  SOFT  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                1000  True
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                1000  True
#
#                                                     SOFT_UPDATE_TAU  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...            0.005
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...            0.005
#
#                                                     EPSILON_DECAY_LAST_FRAME  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                      2000
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                      2000
#
#                                                     EPSILON_START  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...            1.0
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...            1.0
#
#                                                     EPSILON_FINAL  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...           0.02
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...           0.02
#
#                                                     INDEPENDENT_EVALUATION  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                   False
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                   False
#
#                                                     PRINT_INTERVAL  DEVICE
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...               1    cuda
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...               1    cuda
#
# [2 rows x 27 columns]

# %%
runs_root = root + "runs/"
experiments_runs = os.listdir(runs_root)[-NUM_EXPERIMENTS:]
experiments_runs
# Out:
# ['DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39',
#  'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030813-48']

# %%
runs_root = root + "runs/"
experiments_data = {}
for experiment in experiments_df.index:
    if experiment != ".DS_Store":
        for trial in os.listdir(os.path.join(runs_root, experiment)):
            if trial != ".DS_Store":
                for run in os.listdir(os.path.join(runs_root, experiment, trial)):
                    if trial != ".DS_Store":                
                        ea = event_accumulator.EventAccumulator(os.path.join(runs_root, experiment, trial, run))
                        ea.Reload()
                        eid = "-".join([experiment, trial])
                        experiments_data[eid] = None
                        for scalar in ea.Tags()['scalars']:
                            df_temp = pd.DataFrame(ea.Scalars(scalar)).drop('wall_time', axis=1).rename(index=str, columns={'value': scalar})
                            if experiments_data[eid] is None:
                                experiments_data[eid] = df_temp
                            else:
                                experiments_data[eid] = pd.merge(experiments_data[eid], df_temp, how='outer', on='step')

# %%
# listing all experiments
experiments_data.keys()
# Out:
# dict_keys(['DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial0', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial1', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial10', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial11', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial12', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial13', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial14', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial15', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial16', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial17', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial18', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial19', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial2', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial20', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial21', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial22', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent0-trial23', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial0', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial1', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial10', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial11', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial12', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial13', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial14', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial15', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial16', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial17', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial18', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial19', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial2', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial20', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial21', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial22', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial23', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial25', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial26', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial27', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial28', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial29', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial3', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial30', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial31', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial32', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial33', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial34', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial35', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial36', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial37', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial38', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial39', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial4', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial40', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial41', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial42', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223923-39-agent1-trial43', 'DQN_Malmo_Seq-MinecraftBasicNew-v0-2 ...

# %%
len(experiments_data.keys())
# Out:
# 200

# %%
# getting columns from all experiments
sample = list(experiments_data.keys())[1]
experiments_data[sample].columns
# Out:
# Index(['step', 'loss', 'frame_speed', 'epsilon', 'step_reward',
#        'reward_100/avg', 'reward_100/std', 'reward', 'steps', 'ep_speed',
#        'q_value/min', 'q_value/max'],
#       dtype='object')

# %%
# example comparing rewards from within an experiment
plt.figure(figsize=(12,6))
exp_name = sample
for exp,data in experiments_data.items():
    if exp.startswith(exp_name):
        plt.plot(data['reward_100/avg'], label=exp_name)

# %%
# they don't all fit the same timeframe
rewards_exp = defaultdict(list)
for key in experiments_data.keys():
    exp_name = key[:len(experiments_df.index[0])]
    num_episodes = len(experiments_data[key][['reward']].dropna())
    rewards_exp[exp_name].append(num_episodes)

experiment_results = list(zip(rewards_exp.keys(), map(lambda x:np.mean(x), rewards_exp.values())))

df_new = pd.DataFrame(experiment_results, columns=['exp', 'episodes'])
df_new = df_new.set_index('exp')

# %%
df_new
# Out:
#                                                     episodes
# exp
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...     52.47
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...     51.81

# %%
experiments_df.head()
# Out:
#                                                    SEARCH_METHOD  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...    hypothesis
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...    hypothesis
#
#                                                         DEFAULT_ENV_NAME  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...  MinecraftBasicNew-v0
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...  MinecraftBasicNew-v0
#
#                                                            METHOD  NUM_TRIALS  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...  DQN_Malmo_Seq          50
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...  DQN_Malmo_Seq          50
#
#                                                     DEBUG  MAX_GAMES_PLAYED  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...   True               150
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...   True               150
#
#                                                     MEAN_REWARD_BOUND  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                950
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                950
#
#                                                     NUMBER_EPISODES_MEAN  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                    10
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                    10
#
#                                                     NUM_AGENTS  SHARING  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...           2     True
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...           2    False
#
#                                                      ...    GRAD_L2_CLIP  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...   ...               1
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...   ...               1
#
#                                                     SYNC_TARGET_FRAMES  SOFT  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                1000  True
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                1000  True
#
#                                                     SOFT_UPDATE_TAU  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...            0.005
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...            0.005
#
#                                                     EPSILON_DECAY_LAST_FRAME  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                      2000
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                      2000
#
#                                                     EPSILON_START  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...            1.0
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...            1.0
#
#                                                     EPSILON_FINAL  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...           0.02
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...           0.02
#
#                                                     INDEPENDENT_EVALUATION  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                   False
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                   False
#
#                                                     PRINT_INTERVAL  DEVICE
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...               1    cuda
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...               1    cuda
#
# [2 rows x 27 columns]

# %%
experiments_df_rev = pd.merge(experiments_df, df_new, left_index=True, right_index=True)

# %%
experiments_df_rev.sort_values(by='episodes', ascending=True)
# Out:
#                                                    SEARCH_METHOD  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...    hypothesis
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...    hypothesis
#
#                                                         DEFAULT_ENV_NAME  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...  MinecraftBasicNew-v0
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...  MinecraftBasicNew-v0
#
#                                                            METHOD  NUM_TRIALS  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...  DQN_Malmo_Seq          50
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...  DQN_Malmo_Seq          50
#
#                                                     DEBUG  MAX_GAMES_PLAYED  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...   True               150
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...   True               150
#
#                                                     MEAN_REWARD_BOUND  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                950
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                950
#
#                                                     NUMBER_EPISODES_MEAN  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                    10
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                    10
#
#                                                     NUM_AGENTS  SHARING  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...           2    False
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...           2     True
#
#                                                       ...     \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...    ...
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...    ...
#
#                                                     SYNC_TARGET_FRAMES  SOFT  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                1000  True
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                1000  True
#
#                                                     SOFT_UPDATE_TAU  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...            0.005
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...            0.005
#
#                                                     EPSILON_DECAY_LAST_FRAME  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                      2000
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                      2000
#
#                                                     EPSILON_START  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...            1.0
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...            1.0
#
#                                                     EPSILON_FINAL  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...           0.02
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...           0.02
#
#                                                     INDEPENDENT_EVALUATION  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                   False
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                   False
#
#                                                     PRINT_INTERVAL  DEVICE  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...               1    cuda
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...               1    cuda
#
#                                                     episodes
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...     51.81
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...     52.47
#
# [2 rows x 28 columns]

# %%
experiments_df_rev[['GAMMA', 'BATCH_SIZE', 'REPLAY_SIZE', 'LEARNING_RATE', 'SOFT_UPDATE_TAU', 'EPSILON_DECAY_LAST_FRAME', 'SHARING', 'episodes']]
# Out:
#                                                     GAMMA  BATCH_SIZE  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...   0.97         128
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...   0.97         128
#
#                                                     REPLAY_SIZE  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...        10000
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...        10000
#
#                                                     LEARNING_RATE  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...         0.0001
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...         0.0001
#
#                                                     SOFT_UPDATE_TAU  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...            0.005
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...            0.005
#
#                                                     EPSILON_DECAY_LAST_FRAME  \
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...                      2000
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...                      2000
#
#                                                     SHARING  episodes
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...     True     52.47
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...    False     51.81

# %%
# they don't all fit the same timeframe
steps_exp = defaultdict(list)
for key in experiments_data.keys():
    exp_name = key[:len(experiments_df.index[0])]
    num_episodes = experiments_data[key][['steps']].dropna()
    steps_exp[exp_name].append(num_episodes.iloc[-1])
    
experiment_results = list(zip(steps_exp.keys(), map(lambda x:np.mean(x), steps_exp.values())))

df_new = pd.DataFrame(experiment_results, columns=['exp', 'mean of steps'])
df_new = df_new.set_index('exp')
df_new
# Out:
#                                                     mean of steps
# exp
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...          64.38
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...          68.24

# %%
# they don't all fit the same timeframe
aggregate = defaultdict(list)
for key in experiments_data.keys():
    exp_name = key[:len(experiments_df.index[0])]
    num_episodes = experiments_data[key][['reward']].dropna()
    aggregate[exp_name].append(num_episodes.iloc[-1])

    experiment_results = list(zip(steps_exp.keys(), map(lambda x:np.mean(x), aggregate.values())))

df_new = pd.DataFrame(experiment_results, columns=['exp', 'mean of rewards'])
df_new = df_new.set_index('exp')
df_new
# Out:
#                                                     mean of rewards
# exp
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181014-223...          0.00635
# DQN_Malmo_Seq-MinecraftBasicNew-v0-20181015-030...          0.06239

# %%
experiments_data[key][:52]
# Out:
#     step      loss  frame_speed  epsilon  step_reward  reward_100/avg  \
# 0      1  0.001905    27.174862   1.0635       -0.001       -0.072000
# 1      2  0.000966    27.030380   1.0630       -0.001       -0.071500
# 2      3  0.000318    26.790394   1.0625       -0.001       -0.070667
# 3      4  0.001331    27.399067   1.0620       -0.001       -0.070500
# 4      5  0.001748    27.225309   1.0615       -0.001        0.135200
# 5      6  0.001597    27.664358   1.0610       -0.001        0.271167
# 6      7  0.001496    27.107771   1.0605       -0.001        0.222429
# 7      8  0.001013    26.997496   1.0600       -0.001        0.186250
# 8      9  0.000658    27.066662   1.0595       -0.001        0.157444
# 9     10  0.000444    27.102690   1.0590       -0.001        0.134700
# 10    11  0.000324    27.146193   1.0585       -0.001        0.134800
# 11    12  0.000579    27.236271   1.0580       -0.001        0.237300
# 12    13  0.001172    25.490625   1.0575       -0.001        0.237000
# 13    14  0.001600    27.958485   1.0570       -0.001        0.236700
# 14    15  0.001598    27.236624   1.0565       -0.001        0.134300
# 15    16  0.001540    27.603004   1.0560       -0.001        0.132900
# 16    17  0.001439    27.061771   1.0555       -0.001        0.237200
# 17    18  0.001308    25.750093   1.0550       -0.001        0.339800
# 18    19  0.001159    27.815348   1.0545       -0.001        0.340000
# 19    20  0.001015    27.065964   1.0540       -0.001        0.340000
# 20    21  0.000384    27.501829   1.0535       -0.001        0.445400
# 21    22  0.000175    26.950485   1.0530       -0.001        0.443400
# 22    23  0.000195    27.536316   1.0525       -0.001        0.544000
# 23    24  0.000213    33.696766   1.0520       -0.001        0.544700
# 24    25  0.000229    24.134045   1.0515       -0.001        0.544200
# 25    26  0.000233    24.207451   1.0510       -0.001        0.546000
# 26    27  0.000219    26.143160   1.0505       -0.001        0.441800
# 27    28  0.000202    27.030205   1.0500       -0.001        0.444100
# 28    29  0.000204     8.708832   1.0495       -0.001        0.547800
# 29    30  0.000260    13.065350   1.0490       -0.001        0.547700
# 30    31  0.000384    35.825176   1.0485       -0.001        0.442800
# 31    32  0.000500    34.386024   1.0480       -0.001        0.447000
# 32    33  0.000493    27.423431   1.0475       -0.001        0.346800
# 33    34  0.000466    27.168524   1.0470       -0.001        0.451700
# 34    35  0.000431    26.313240   1.0465       -0.001        0.556300
# 35    36  0.000394    27.760485   1.0460       -0.001        0.453700
# 36    37  0.000388    26.802891   1.0455       -0.001        0.558700
# 37    38  0.000387    26.635067   1.0450       -0.001        0.556200
# 38    39  0.000380    27.228138   1.0445       -0.001        0.558600
# 39    40  0.000370    27.026896   1.0440       -0.001        0.664400
# 40    41  0.000339    27.414110   1.0435       -0.001        0.770000
# 41    42  0.000310    27.389227   1.0430       -0.001        0.665400
# 42    43  0.000278    30.871342   1.0425       -0.001        0.666100
# 43    44  0.000227    26.731487   1.0420       -0.001        0.666200
# 44    45  0.000199    27.243702   1.0415       -0.001        0.664400
# 45    46  0.000196    23.243452   1.0410       -0.001        0.770800
# 46    47  0.000191    24.124189   1.0405       -0.001        0.771500
# 47    48  0.000200    27.686089   1.0400       -0.001        0.774700
# 48    49  0.000210    27.123898   1.0395       -0.001        0.773900
# 49    50  0.000235    27.277010   1.0390       -0.001        0.774500
# 50    51  0.000243    27.124599   1.0385       -0.001        0.772200
# 51    52  0.000238    26.317368   1.0380       -0.001        0.878300
#
#     reward_100/std  reward  steps  ep_speed  q_value/min  q_value/max
# 0         0.000000  -0.071   72.0  0.283651          NaN          NaN
# 1         0.000500  -0.069   70.0  0.280131          NaN          NaN
# 2         0.001247  -0.070   70.0  0.266126          NaN          NaN
# 3         0.001118   0.958   42.0  0.281366          NaN          NaN
# 4         0.411401   0.951   49.0  0.436971          NaN          NaN
# 5         0.483195  -0.070   71.0  0.399032          NaN          NaN
# 6         0.463007  -0.067   68.0  0.286769          NaN          NaN
# 7         0.443555  -0.073   74.0  0.289098          NaN          NaN
# 8         0.426050  -0.070   70.0  0.273441          NaN          NaN
# 9         0.409906  -0.071   71.0  0.282596          NaN          NaN
# 10        0.409856   0.954   46.0  0.285566          NaN          NaN
# 11        0.469413  -0.072   73.0  0.367953          NaN          NaN
# 12        0.469610  -0.073   74.0  0.286283          NaN          NaN
# 13        0.469807  -0.066   67.0  0.264393          NaN          NaN
# 14        0.409106   0.937   63.0  0.282409          NaN          NaN
# 15        0.406324   0.973   27.0  0.295685          NaN          NaN
# 16        0.469766   0.959   41.0  0.628093          NaN          NaN
# 17        0.502990  -0.071   71.0  0.420349          NaN          NaN
# 18        0.502827  -0.070   71.0  0.287351          NaN          NaN
# 19        0.502827   0.983   17.0  0.285888          NaN          NaN
# 20        0.515925   0.934   66.0  0.849488          NaN          NaN
# 21        0.513984   0.934   66.0  0.308376          NaN          NaN
# 22        0.501562  -0.066   67.0  0.287938          NaN          NaN
# 23        0.500705  -0.071   72.0  0.284315          NaN          NaN
# 24        0.501316   0.955   45.0  0.272005          NaN          NaN
# 25        0.502754  -0.069   70.0  0.399142          NaN          NaN
# 26        0.511364   0.982   18.0  0.274602          NaN          NaN
# 27        0.513732   0.966   34.0  0.700641          NaN          NaN
# 28        0.503857  -0.071   72.0  0.521731          NaN          NaN
# 29        0.503979  -0.066   67.0  0.268500          NaN          NaN
# 30        0.511571   0.976   24.0  0.280897          NaN          NaN
# 31        0.515742  -0.068   68.0  0.641431          NaN          NaN
# 32        0.508680   0.983   17.0  0.288437          NaN          NaN
# 33        0.520756   0.975   25.0  0.823782          NaN          NaN
# 34        0.510204  -0.071   72.0  0.644747          NaN          NaN
# 35        0.522719   0.981   19.0  0.280233          NaN          NaN
# 36        0.512536   0.957   43.0  0.563303          NaN          NaN
# 37        0.510523   0.990   10.0  0.375866          NaN          NaN
# 38        0.512496   0.987   13.0  1.011249          NaN          NaN
# 39        0.479762   0.990   10.0  0.965838          NaN          NaN
# 40        0.419849  -0.070   71.0  0.930240          NaN          NaN
# 41        0.481299  -0.061   62.0  0.286313          NaN          NaN
# 42        0.480236   0.984   16.0  0.281891          NaN          NaN
# 43        0.480302   0.957   43.0  0.755200          NaN          NaN
# 44        0.479174   0.993    7.0  0.371461          NaN          NaN
# 45        0.418333   0.988   12.0  1.319978          NaN          NaN
# 46        0.418690   0.989   11.0  0.990250          NaN          NaN
# 47        0.420215   0.982   18.0  0.944055          NaN          NaN
# 48        0.419812   0.993    7.0  0.815166          NaN          NaN
# 49        0.420120   0.967   33.0  0.901972          NaN          NaN
# 50        0.418996   0.991    9.0  0.440713          NaN          NaN
# 51        0.313301   0.987   13.0  1.072939          NaN          NaN

# %% [markdown]
# Mean of steps is a little lower, mean of rewards higher. On the metric that matters (number of episodes) is worst
